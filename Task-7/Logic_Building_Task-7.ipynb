# %% [markdown]
# ## Logic Building Task 7

# %%
# Problem 1 - Smart Light Controller

class SmartLight:
    
    def __init__(self, light_name):
        self.light_name = light_name
        self.status = "OFF"
    
    def turn_on(self):
        self.status = "ON"
        print(f"{self.light_name} is ON")
    
    def turn_off(self):
        self.status = "OFF"
        print(f"{self.light_name} is OFF")
    
    def display_status(self):
        print(f"{self.light_name} current status: {self.status}")


# Usage
light = SmartLight("Bedroom Light")
light.turn_on()
light.display_status()
# Out:
# Bedroom Light is ON
# Bedroom Light current status: ON

# %%
# Problem 2 - Employee ID Card System

class EmployeeIDCard:
    
    def __init__(self, name, emp_id, department):
        self.name = name
        self.emp_id = emp_id
        self.department = department
    
    def display_id_card(self):
        print("Employee ID Card")
        print("Name:", self.name)
        print("ID:", self.emp_id)
        print("Department:", self.department)


# Usage
employee = EmployeeIDCard("Rahul", "EMP102", "IT")
employee.display_id_card()
# Out:
# Employee ID Card
# Name: Rahul
# ID: EMP102
# Department: IT

# %%
# Problem 3 - Mobile Contact Record

class Contact:
    
    def __init__(self, name, phone):
        self.name = name
        self.phone = phone
    
    def save_contact(self):
        print("Contact Saved")
        print("Name:", self.name)
        print("Phone:", self.phone)


# Usage
contact = Contact("Anita", 9876543210)
contact.save_contact()
# Out:
# Contact Saved
# Name: Anita
# Phone: 9876543210

# %%
# Problem 4 - Product Price Tag Generator

class Product:
    
    def __init__(self, name, price):
        self.name = name
        self.price = price
    
    def display_price_tag(self):
        print("Product:", self.name)
        print(f"Price: ₹{self.price}")


# Usage
product = Product("Headphones", 2499)
product.display_price_tag()
# Out:
# Product: Headphones
# Price: ₹2499

# %%
# Problem 5 - Movie Rating Display System

class Movie:
    
    def __init__(self, name, rating):
        self.name = name
        self.rating = rating
    
    def display_details(self):
        print("Movie:", self.name)
        print(f"Rating: {self.rating} / 5")


# Usage
movie = Movie("Inception", 4.8)
movie.display_details()
# Out:
# Movie: Inception
# Rating: 4.8 / 5

# %%
# Problem 6 - Delivery Address Manager

class Delivery:
    
    def __init__(self, customer_name, address):
        self.customer_name = customer_name
        self.address = address
    
    def display_delivery_details(self):
        print("Delivery Details")
        print("Customer:", self.customer_name)
        print("Address:", self.address)


# Usage
delivery = Delivery("Suman", "Hyderabad")
delivery.display_delivery_details()
# Out:
# Delivery Details
# Customer: Suman
# Address: Hyderabad

# %% [markdown]
# ## Conclusion
#
# This assignment demonstrates fundamental OOPS concepts including:
#
# - Class creation
# - Constructors (__init__)
# - Instance variables
# - Methods
# - Encapsulation of data and behavior
#
# Each class simulates a real-world system such as smart home automation,
# HR systems, retail billing, streaming platforms, and logistics platforms.
#
# This task strengthens object-oriented design thinking and modular programming.
